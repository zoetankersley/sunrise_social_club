# %% [markdown]
# # Sunrise Social Club- Project Log
# ## 6/11 Data Pipeline Setup
# - Downloaded raw sales data
# - Setup project architecture in VS Code
# - Merged datasets (sales, weather, events)
# - Cleaned and standardized the initial dataset
# - Determined what columns I needed
# - Had to separate addons into flavors and cold foam
# - Had to split modifiers into size and milk
# - Had to refamiliarize myself with git/version control
#
# **Key Learnings:**
# - Data cleaning is tedious but helps in the long run
# - Merging multiple CSV sources introduces duplicate column issues
# - Weather dataset from NOAA was unavailable, so I had to fallback to manual inputs
#
# ## 6/12 Feature Engineering
# - Added special drinks dictionary for known signature items
# - Refined flavor extraction logic
# - Removed “Lemonade” from flavor category (moved to base concept)
# - Introduced explicit Base column
#
# **Key Learnings:**
# - Data modeling decisions affect all downstream analysis
# - “Flavor” must represent true add-ons, not base ingredients
# - Signature items require consistent mapping strategy
